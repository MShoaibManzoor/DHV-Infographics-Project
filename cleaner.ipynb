# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./EO108_18122023160120750.csv')
df
# Out:
#     LOCATION         Country VARIABLE                          Variable  \
# 0        GBR  United Kingdom     WSST  Compensation rate, total economy
# 1        GBR  United Kingdom     WSST  Compensation rate, total economy
# 2        GBR  United Kingdom     WSST  Compensation rate, total economy
# 3        GBR  United Kingdom     WSST  Compensation rate, total economy
# 4        GBR  United Kingdom     WSST  Compensation rate, total economy
# ..       ...             ...      ...                               ...
# 124      GBR  United Kingdom      POP                  Total population
# 125      GBR  United Kingdom      POP                  Total population
# 126      GBR  United Kingdom      POP                  Total population
# 127      GBR  United Kingdom      POP                  Total population
# 128      GBR  United Kingdom      POP                  Total population
#
#     FREQUENCY Frequency  TIME  Time         Value  Flag Codes  Flags
# 0           A    Annual  2012  2012  3.323942e+04         NaN    NaN
# 1           A    Annual  2013  2013  3.431918e+04         NaN    NaN
# 2           A    Annual  2014  2014  3.464974e+04         NaN    NaN
# 3           A    Annual  2015  2015  3.494091e+04         NaN    NaN
# 4           A    Annual  2016  2016  3.600354e+04         NaN    NaN
# ..        ...       ...   ...   ...           ...         ...    ...
# 124         A    Annual  2018  2018  6.643600e+07         NaN    NaN
# 125         A    Annual  2019  2019  6.683300e+07         NaN    NaN
# 126         A    Annual  2020  2020  6.722293e+07         NaN    NaN
# 127         A    Annual  2021  2021  6.758545e+07         NaN    NaN
# 128         A    Annual  2022  2022  6.790412e+07         NaN    NaN
#
# [129 rows x 11 columns]

# %%
# Checking data characteristics.
characteristics = pd.concat([df.isnull().sum(), df.nunique(), df.dtypes],
                        keys=['Null Values', 'Unique Values', 'Data Types'],
                        axis=1)
characteristics
# Out:
#             Null Values  Unique Values Data Types
# LOCATION              0              1     object
# Country               0              1     object
# VARIABLE              0             12     object
# Variable              0             12     object
# FREQUENCY             0              1     object
# Frequency             0              1     object
# TIME                  0             11      int64
# Time                  0             11      int64
# Value                 0            127    float64
# Flag Codes          129              0    float64
# Flags               129              0    float64

# %%
dump_columns = ['LOCATION', 'Country', 'VARIABLE', 'FREQUENCY', 'Frequency', 'TIME', 'Flag Codes', 'Flags']
for column in dump_columns:
    if column in df.columns:
        df = df.drop(columns=[column])
    else:
        print("{} is not the Dataset!".format(column))

# %%
df.describe()
# Out:
#               Time         Value
# count   129.000000  1.290000e+02
# mean   2016.906977 -1.245578e+10
# std       3.148516  2.512990e+10
# min    2012.000000 -1.083900e+11
# 25%    2014.000000 -1.778100e+10
# 50%    2017.000000  3.139163e+04
# 75%    2020.000000  2.969700e+07
# max    2022.000000  6.790412e+07

# %%
df
# Out:
#                              Variable  Time         Value
# 0    Compensation rate, total economy  2012  3.323942e+04
# 1    Compensation rate, total economy  2013  3.431918e+04
# 2    Compensation rate, total economy  2014  3.464974e+04
# 3    Compensation rate, total economy  2015  3.494091e+04
# 4    Compensation rate, total economy  2016  3.600354e+04
# ..                                ...   ...           ...
# 124                  Total population  2018  6.643600e+07
# 125                  Total population  2019  6.683300e+07
# 126                  Total population  2020  6.722293e+07
# 127                  Total population  2021  6.758545e+07
# 128                  Total population  2022  6.790412e+07
#
# [129 rows x 3 columns]

# %%
df.to_csv('cleaned.csv')

# %%
economic_outlook = pd.read_csv('./EO108_25122023171635775.csv')
economic_outlook
# Out:
#     LOCATION  Country VARIABLE                        Variable FREQUENCY  \
# 0        FRA   France      CBD  Current account balance in USD         A
# 1        FRA   France      CBD  Current account balance in USD         A
# 2        FRA   France      CBD  Current account balance in USD         A
# 3        FRA   France      CBD  Current account balance in USD         A
# 4        FRA   France      CBD  Current account balance in USD         A
# ..       ...      ...      ...                             ...       ...
# 283      DEU  Germany      POP                Total population         A
# 284      DEU  Germany      POP                Total population         A
# 285      DEU  Germany      POP                Total population         A
# 286      DEU  Germany      POP                Total population         A
# 287      DEU  Germany      POP                Total population         A
#
#     Frequency  TIME  Time         Value  Flag Codes  Flags
# 0      Annual  2012  2012 -2.588844e+10         NaN    NaN
# 1      Annual  2013  2013 -1.436132e+10         NaN    NaN
# 2      Annual  2014  2014 -2.790670e+10         NaN    NaN
# 3      Annual  2015  2015 -8.891354e+09         NaN    NaN
# 4      Annual  2016  2016 -1.212644e+10         NaN    NaN
# ..        ...   ...   ...           ...         ...    ...
# 283    Annual  2018  2018  8.290600e+07         NaN    NaN
# 284    Annual  2019  2019  8.309300e+07         NaN    NaN
# 285    Annual  2020  2020  8.326615e+07         NaN    NaN
# 286    Annual  2021  2021  8.341710e+07         NaN    NaN
# 287    Annual  2022  2022  8.353422e+07         NaN    NaN
#
# [288 rows x 11 columns]

# %%
dump_columns = ['LOCATION', 'VARIABLE', 'FREQUENCY', 'Frequency', 'TIME', 'Flag Codes', 'Flags']
for column in dump_columns:
    if column in economic_outlook.columns:
        economic_outlook = economic_outlook.drop(columns=[column])
    else:
        print("{} is not the Dataset!".format(column))

# %%
eo_characteristics = pd.concat([economic_outlook.isnull().sum(), economic_outlook.nunique(), economic_outlook.dtypes],
                        keys=['Null Values', 'Unique Values', 'Data Types'],
                        axis=1)
eo_characteristics
# Out:
#           Null Values  Unique Values Data Types
# Country             0              3     object
# Variable            0              9     object
# Time                0             11      int64
# Value               0            288    float64

# %%
economic_outlook.to_csv('eo_cleaned.csv')

# %%
df_immigration = pd.read_csv('./Immigration_reason_stats.csv')

# %%
columns = df_immigration.columns[1:]
df_immigration = df_immigration.groupby('Time')[columns].mean().reset_index()

# %%
df_immigration = df_immigration.round(0).astype(int)
df_immigration.to_csv('immigration_stats_cleaned.csv')

# %%
path = './UNDP_HDI_Trends&Characteristics.xlsx'
hdi_char = pd.read_excel(path, sheet_name='HDI characteristics')
hdi_trends = pd.read_excel(path, sheet_name='HDI trends')
hdi_growth = pd.read_excel(path, sheet_name='HDI average growth (annual)', skiprows=1)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample DataFrame
data = {'Category': ['Category A', 'Category B', 'Category C'],
        'Value 1': [10, 25, 5],
        'Value 2': [20, 15, 10]}
df = pd.DataFrame(data)

# Create a subplot
fig, ax = plt.subplots(figsize=(8, 4))

# Hide the axes
ax.axis('off')

# Display the DataFrame as a table
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center', edges='horizontal')

# Customize the appearance of the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)

# Add a title
ax.set_title('DataFrame Table in a Subplot')

# Show the plot
plt.show()
# Out:
# array([['Category A', 10, 20],
#        ['Category B', 25, 15],
#        ['Category C', 5, 10]], dtype=object)
